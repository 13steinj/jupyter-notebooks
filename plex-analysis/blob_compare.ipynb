# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw_idle()
    
widg = widgets.FloatSlider(value=7.5, min=1, max=5.0, step=0.5)
display(widg)
interact(update, w = widg);
# Out:
# <img src="data:image/png;base64,..." width="640">
# FloatSlider(value=5.0, max=5.0, min=1.0, step=0.5)
# interactive(children=(FloatSlider(value=5.0, description='w', max=5.0, min=1.0, step=0.5), Output()), _dom_cla…
